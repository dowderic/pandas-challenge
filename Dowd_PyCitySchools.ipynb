# %% [markdown]
# # Eric Dowd PyCitySchools Code

# %%
#PyCitySchools Analysis
#loading pandas library
import pandas as pd

#school and student files
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Reading school and student data into data frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
total_schools_count = len(school_data["School ID"].unique())
total_student_count=len(student_data["Student ID"].unique())
total_budget=sum(school_data["budget"])
avg_math_score=student_data["math_score"].mean()
avg_reading_score=student_data["reading_score"].mean()

# %% [markdown]
# # District Summary

# %%
district_summary_df = pd.DataFrame({"Total Schools": [total_schools_count],"Total Students": [total_student_count],
                                    "Total Budget": [total_budget],"Average Math Score": avg_math_score,
                                  "Average Reading Score": avg_reading_score})


district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score
# 0               81.87784

# %%
grouped_school_df = school_data_complete.groupby(['school_name'])

grouped_avg_math_score=grouped_school_df["math_score"].mean()
grouped_avg_reading_score=grouped_school_df["reading_score"].mean()
grouped_tot_students=grouped_school_df["reading_score"].count()
grouped_tot_budget=grouped_school_df["budget"].mean()
grouped_perstud_budget=grouped_tot_budget/grouped_tot_students
grouped_school_df.head()
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 37535       37535         Norma Mata      F  10th  Thomas High School
# 37536       37536        Cody Miller      M  11th  Thomas High School
# 37537       37537        Erik Snyder      M   9th  Thomas High School
# 37538       37538     Tanya Martinez      F   9th  Thomas High School
# 37539       37539      Noah Erickson      M   9th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
school_summary_df = pd.DataFrame({"School Type": type,
                                  "Total Students": grouped_tot_students,"Total School Budget": grouped_tot_budget,
                                  "Per Student Budget": grouped_perstud_budget,
                                  "Average Math Score": grouped_avg_math_score,
                                  "Average Reading Score": grouped_avg_reading_score})
school_summary_df
# Out:
#                           School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School     <class 'type'>            4976              3124928
# Cabrera High School    <class 'type'>            1858              1081356
# Figueroa High School   <class 'type'>            2949              1884411
# Ford High School       <class 'type'>            2739              1763916
# Griffin High School    <class 'type'>            1468               917500
# Hernandez High School  <class 'type'>            4635              3022020
# Holden High School     <class 'type'>             427               248087
# Huang High School      <class 'type'>            2917              1910635
# Johnson High School    <class 'type'>            4761              3094650
# Pena High School       <class 'type'>             962               585858
# Rodriguez High School  <class 'type'>            3999              2547363
# ...
